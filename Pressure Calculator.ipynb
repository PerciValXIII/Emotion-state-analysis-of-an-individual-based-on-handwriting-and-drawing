# %%
import pandas as pd

# %%
data = pd.read_csv("6.csv")

# %%
data
# Out:
#                     2856 Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0     9911 36061 4646386        NaN         NaN        NaN         NaN
# 1     9945 36030 4646394        NaN         NaN        NaN         NaN
# 2     9961 36024 4646401        NaN         NaN        NaN         NaN
# 3     9974 36021 4646409        NaN         NaN        NaN         NaN
# 4     9989 36021 4646416        NaN         NaN        NaN         NaN
# ...                  ...        ...         ...        ...         ...
# 2874                6928      16913         NaN        NaN   4669630.0
# 2875                6835      16831         NaN        NaN   4669638.0
# 2876                6752      16767         NaN        NaN   4669645.0
# 2877                6687      16717         NaN        NaN   4669653.0
# 2878                6643      16685         NaN        NaN   4669660.0
#
#      Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
data = data.iloc[:,13:14]

# %%
data = data.fillna(0)

# %%
data
# Out:
#       Unnamed: 13
# 0             158
# 1             168
# 2             228
# 3             296
# 4             348
# ...           ...
# 2874          654
# 2875          662
# 2876          662
# 2877          627
# 2878          488
#
# [2879 rows x 1 columns]

# %%
data.mean()
# Out:
# Unnamed: 13    431.931921
# dtype: float64
